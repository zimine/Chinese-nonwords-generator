# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt    # import matplotlib
import numpy as np                 # import numpy
import scipy as sp                 # import scipy
import scipy.stats
import math                        # import basic math functions
import random                      # import basic random number generator functions
import pandas as pd
import jieba as jb
import itertools
from itertools import combinations, permutations, repeat

# %%
#-------------------------9th step--------------------------
df1 = pd.read_csv("/Users/zimine/Documents/MPhil/Stimuli/Data/df1_ver_3.csv", index_col = 0)
df1
# Out:
#       Character-1 Character-2 Word_Trad Word_Sim  Stroke-1  Stroke-2  \
# 0               一           刀        一刀       一刀       1.0       2.0
# 1               一           口        一口       一口       1.0       3.0
# 2               一           分        一分       一分       1.0       4.0
# 3               一           切        一切       一切       1.0       4.0
# 4               一           心        一心       一心       1.0       4.0
# 5               一           手        一手       一手       1.0       4.0
# 6               一           斤        一斤       一斤       1.0       4.0
# 7               一           半        一半       一半       1.0       5.0
# 8               一           旦        一旦       一旦       1.0       5.0
# 9               一           生        一生       一生       1.0       5.0
# 10              一           共        一共       一共       1.0       6.0
# 11              一           再        一再       一再       1.0       6.0
# 12              一           同        一同       一同       1.0       6.0
# 13              一           向        一向       一向       1.0       6.0
# 14              一           早        一早       一早       1.0       6.0
# 15              一           些        一些       一些       1.0       8.0
# 16              一           并        一併       一并       1.0       8.0
# 17              一           来        一來       一来       1.0       8.0
# 18              一           味        一味       一味       1.0       8.0
# 19              一           定        一定       一定       1.0       8.0
# 20              一           直        一直       一直       1.0       8.0
# 21              一           则        一則       一则       1.0       9.0
# 22              一           度        一度       一度       1.0       9.0
# 23              一           律        一律       一律       1.0       9.0
# 24              一           流        一流       一流       1.0       9.0
# 25              一           致        一致       一致       1.0      10.0
# 26              一           面        一面       一面       1.0       9.0
# 27              一           旁        一旁       一旁       1.0      10.0
# 28              一           时        一時       一时       1.0      10.0
# 29              一           般        一般       一般       1.0      10.0
# ...           ...         ...       ...      ...       ...       ...
# 25251           缆           车        纜車       缆车      25.0       7.0
# 25252           缆           索        纜索       缆索      25.0      10.0
# 25253           缆           绳        纜繩       缆绳      25.0      19.0
# 25254           钻           入        鑽入       钻入      27.0       2.0
# 25255           钻           井        鑽井       钻井      27.0       4.0
# 25256           钻           孔        鑽孔       钻孔      27.0       4.0
# 25257           钻           出        鑽出       钻出      27.0       5.0
# 25258           钻           石        鑽石       钻石      27.0       5.0
# 25259           钻           戒        鑽戒       钻戒      27.0       7.0
# 25260           钻           空        鑽空       钻空      27.0       8.0
# 25261           钻           洞        鑽洞       钻洞      27.0       9.0
# 25262           钻           研        鑽研       钻研      27.0       9.0
# 25263           钻           探        鑽探       钻探      27.0      11.0
# 25264           钻           进        鑽進       钻进      27.0      12.0
# 25265           钻           开        鑽開       钻开      27.0      12.0
# 25266           钻           头        鑽頭       钻头      27.0      16.0
# 25267           颧           骨        顴骨       颧骨      27.0      10.0
# 25268           鳄           鱼        鱷魚       鳄鱼      27.0      11.0
# 25269           鲈           鱼        鱸魚       鲈鱼      27.0      11.0
# 25270           戆           直        戇直       戆直      28.0       8.0
# 25271           凿           井        鑿井       凿井      28.0       4.0
# 25272           凿           洞        鑿洞       凿洞      28.0       9.0
# 25273           凿           墙        鑿牆       凿墙      28.0      17.0
# 25274           鹦           鹉        鸚鵡       鹦鹉      28.0      19.0
# 25275           郁           闷        鬱悶       郁闷      30.0      12.0
# 25276           郁           结        鬱結       郁结      30.0      12.0
# 25277           劏           猪        劏豬       劏猪      15.0      15.0
# 25278           劏           鸡        劏雞       劏鸡      15.0      18.0
# 25279           嫲           嫲        嫲嫲       嫲嫲      14.0      14.0
# 25280           腼           腆        腼腆       腼腆      13.0      12.0
#
#        C&B-Subtitle-raw-C1  C&B-Subtitle-raw-C2  C&B-Subtitle-raw-W  HD-1  \
# 0                 604056.0               4999.0                 NaN  10.0
# 1                 604056.0              21385.0                 NaN  10.0
# 2                 604056.0              48396.0               952.0  10.0
# 3                 604056.0              28202.0             21709.0  10.0
# 4                 604056.0              83418.0               137.0  10.0
# 5                 604056.0              75608.0               107.0  10.0
# 6                 604056.0                369.0                 NaN  10.0
# 7                 604056.0              10910.0              2633.0  10.0
# 8                 604056.0               3661.0              2922.0  10.0
# 9                 604056.0             162725.0              2437.0  10.0
# 10                604056.0               7769.0               507.0  10.0
# 11                604056.0              78039.0                68.0  10.0
# 12                604056.0              42995.0               276.0  10.0
# 13                604056.0              24596.0               510.0  10.0
# 14                604056.0              26160.0               326.0  10.0
# 15                604056.0             113122.0             17133.0  10.0
# 16                604056.0              26283.0                27.0  10.0
# 17                604056.0             377902.0               162.0  10.0
# 18                604056.0              11803.0                10.0  10.0
# 19                604056.0              81657.0             20273.0  10.0
# 20                604056.0              46163.0             24551.0  10.0
# 21                604056.0               8312.0                 8.0  10.0
# 22                604056.0              17384.0                80.0  10.0
# 23                604056.0              12028.0                31.0  10.0
# 24                604056.0              11946.0               346.0  10.0
# 25                604056.0               6199.0              1087.0  10.0
# 26                604056.0              67015.0               887.0  10.0
# 27                604056.0               3900.0               129.0  10.0
# 28                604056.0             162611.0               583.0  10.0
# 29                604056.0               4611.0              2586.0  10.0
# ...                    ...                  ...                 ...   ...
# 25251                277.0              55587.0                47.0   5.0
# 25252                277.0               8632.0                 4.0   5.0
# 25253                277.0               1679.0                42.0   5.0
# 25254               2373.0              24269.0                 NaN   1.0
# 25255               2373.0               1114.0                32.0   1.0
# 25256               2373.0               1301.0                49.0   1.0
# 25257               2373.0             129404.0                 NaN   1.0
# 25258               2373.0               6896.0              1162.0   1.0
# 25259               2373.0               4018.0                53.0   1.0
# 25260               2373.0              15517.0                 NaN   1.0
# 25261               2373.0               2997.0                 NaN   1.0
# 25262               2373.0               4263.0                30.0   1.0
# 25263               2373.0              12125.0                38.0   1.0
