# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt    # import matplotlib
import numpy as np                 # import numpy
import scipy as sp                 # import scipy
import scipy.stats
import math                        # import basic math functions
import random                      # import basic random number generator functions
import pandas as pd
import jieba as jb
import itertools
from itertools import combinations, permutations, repeat

# %%
df2 = pd.read_csv("/Users/zimine/Documents/MPhil/MPhil project/Stimuli/Data/df1_ver_6.csv", index_col = 0)
df2
# Out:
#       Character-1 Character-2 Word_Trad Word_Sim  Stroke-1  Stroke-2  \
# 0               一           刀        一刀       一刀         1         2
# 1               一           口        一口       一口         1         3
# 2               一           分        一分       一分         1         4
# 3               一           切        一切       一切         1         4
# 4               一           心        一心       一心         1         4
# 5               一           手        一手       一手         1         4
# 6               一           斤        一斤       一斤         1         4
# 7               一           半        一半       一半         1         5
# 8               一           旦        一旦       一旦         1         5
# 9               一           生        一生       一生         1         5
# 10              一           共        一共       一共         1         6
# 11              一           再        一再       一再         1         6
# 12              一           同        一同       一同         1         6
# ...

# %%
df2.loc[df2['Word_Sim'] == '今天']
df2.loc[df2['Word_Sim'] == '故事']
df2.loc[df2['Word_Sim'] == '警察']
df2.loc[df2['Word_Sim'] == '数字']
df2.loc[df2['Word_Sim'] == '母亲']
df2.loc[df2['Word_Sim'] == '早晨']
df2.loc[df2['Word_Sim'] == '分钟']
df2.loc[df2['Word_Sim'] == '猜想']
df2.loc[df2['Word_Sim'] == '女孩']
df2.loc[df2['Word_Sim'] == '死亡']
df2.loc[df2['Word_Sim'] == '原因']
df2.loc[df2['Word_Sim'] == '机会']
df2.loc[df2['Word_Sim'] == '改变']
df2.loc[df2['Word_Sim'] == '检查']
df2.loc[df2['Word_Sim'] == '商业']
df2.loc[df2['Word_Sim'] == '婴儿']
df2.loc[df2['Word_Sim'] == '兄弟']
df2.loc[df2['Word_Sim'] == '课程']
df2.loc[df2['Word_Sim'] == '借口']
df2.loc[df2['Word_Sim'] == '主意']
df2.loc[df2['Word_Sim'] == '思维']
df2.loc[df2['Word_Sim'] == '麻烦']
df2.loc[df2['Word_Sim'] == '女人']
df2.loc[df2['Word_Sim'] == '世界']
df2.loc[df2['Word_Sim'] == '钱财']
df2.loc[df2['Word_Sim'] == '女士']
df2.loc[df2['Word_Sim'] == '蜂蜜']
df2.loc[df2['Word_Sim'] == '晚餐']
df2.loc[df2['Word_Sim'] == '聚会']
df2.loc[df2['Word_Sim'] == '窗户']
df2.loc[df2['Word_Sim'] == '桌子']
df2.loc[df2['Word_Sim'] == '夏天']
df2.loc[df2['Word_Sim'] == '姐姐']
df2.loc[df2['Word_Sim'] == '服务']
df2.loc[df2['Word_Sim'] == '报告']
df2.loc[df2['Word_Sim'] == '原因']
df2.loc[df2['Word_Sim'] == '唱片']
df2.loc[df2['Word_Sim'] == '承诺']
df2.loc[df2['Word_Sim'] == '监狱']
df2.loc[df2['Word_Sim'] == '图片']
df2.loc[df2['Word_Sim'] == '父母']
df2.loc[df2['Word_Sim'] == '伙伴']
df2.loc[df2['Word_Sim'] == '文件']
df2.loc[df2['Word_Sim'] == '顺序']
df2.loc[df2['Word_Sim'] == '时刻']
df2.loc[df2['Word_Sim'] == '会议']
df2.loc[df2['Word_Sim'] == '信息']
df2.loc[df2['Word_Sim'] == '婚姻']
df2.loc[df2['Word_Sim'] == '主人']
df2.loc[df2['Word_Sim'] == '主修']
df2.loc[df2['Word_Sim'] == '字母']
df2.loc[df2['Word_Sim'] == '荣誉']
df2.loc[df2['Word_Sim'] == '酒店']
df2.loc[df2['Word_Sim'] == '未来']
df2.loc[df2['Word_Sim'] == '好处']
df2.loc[df2['Word_Sim'] == '感受']
df2.loc[df2['Word_Sim'] == '美元']
df2.loc[df2['Word_Sim'] == '女儿']
df2.loc[df2['Word_Sim'] == '封面']
df2.loc[df2['Word_Sim'] == '学院']
df2.loc[df2['Word_Sim'] == '身体']
df2.loc[df2['Word_Sim'] == '攻击']
df2.loc[df2['Word_Sim'] == '区域']
df2.loc[df2['Word_Sim'] == '军队']
df2.loc[df2['Word_Sim'] == '天使']
df2.loc[df2['Word_Sim'] == '代理']
df2.loc[df2['Word_Sim'] == '想法']
df2.loc[df2['Word_Sim'] == '地区']
df2.loc[df2['Word_Sim'] == '光荣']
df2.loc[df2['Word_Sim'] == '会面']
df2.loc[df2['Word_Sim'] == '袭击']
df2.loc[df2['Word_Sim'] == '记载']
df2.loc[df2['Word_Sim'] == '主人']
df2.loc[df2['Word_Sim'] == '肮脏']
# Out:
#       Character-1 Character-2 Word_Trad Word_Sim  Stroke-1  Stroke-2  \
# 20204           肮           脏        骯髒       肮脏        14        23
#
#        C&B-Subtitle-raw-C1  C&B-Subtitle-log-C1  C&B-Subtitle-raw-C2  \
# 20204                658.0                 2.82               5786.0
#
#        C&B-Subtitle-log-C2  C&B-Subtitle-raw-W  C&B-Subtitle-log-W  HD-1  \
# 20204                 3.76               655.0                2.82   3.0
#
#        HD-2  Num-neighbor-1  Num-neighbor-2  Stroke_M  HD_M
# 20204   4.0           276.0           304.0      18.5   3.5

# %%
df3 = df2.loc[df2['Word_Sim'].str.contains('女人|世界|麻烦|思维|今天|故事|警察|数字|早晨|母亲|分钟|主意|猜想|女孩|借口|死亡|课程|机会|改变|检查|商业|兄弟|婴儿|钱财|女士|蜂蜜|晚餐|聚会|父亲|窗户|桌子|夏天|姐姐|服务|报告|原因|唱片|承诺|图片|父母|伙伴|文件|顺序|时刻|会议|信息|婚姻|主人|主修|字母|荣誉|酒店|未来|好处|感受|女儿|封面|学院|身体|攻击|区域|军队|天使|代理|ang z')]
df3.to_csv('stimuli_ver1.csv')

# %%
df5 = df4.loc[df4['HD_M'] >= 6]
df6 = df5.loc[df5['HD_M'] <= 20]

# %%
df6.loc[df6['Word_Sim'] == '世界']
# Out:
#      Character-1 Character-2 Word_Trad Word_Sim  Stroke-1  Stroke-2  \
# 1837           世           界        世界       世界         5         9
#
#       C&B-Subtitle-raw-C1  C&B-Subtitle-log-C1  C&B-Subtitle-raw-C2  \
# 1837              21566.0                 4.33              15995.0
#
#       C&B-Subtitle-log-C2  C&B-Subtitle-raw-W  C&B-Subtitle-log-W  HD-1  HD-2  \
# 1837                  4.2             11721.0                4.07  29.0   8.0
#
#       Num-neighbor-1  Num-neighbor-2  Stroke_M  HD_M
# 1837           306.0           306.0       7.0  18.5
